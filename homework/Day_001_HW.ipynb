# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y-yp)**2)/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 220.002
# The Mean absolute error is 12.003

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# ### 1. 你選的這組資料為何重要
#
# 答：
# 資料：Airline Delay and Cancellation Data, 2009 - 2018
# 該組資料涵蓋了9年的航班延遲與取消資料，除了清楚記載全美的航班準點與否，亦有起降機場、延遲或取消原因等相關資料。若能妥善分析、運用這時間序列資料，將提供飛航安全與乘客權益更大的幫助。
#
# ### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 答：
# 全資料是經OST website中下載，該網站是為美國運輸部（US Department of Transportation）所提供之網路平台，提供各項運輸系統之公開資料。
#
#
# ### 3. 蒐集而來的資料型態為何
#
# 答：
# 該組資料透過年份，分為9份csv的資料。
#
# ### 4. 這組資料想解決的問題如何評估
#
# 答：
# 為透過時間分成的資料，除了透過年份分類之外，各筆資料都記載著當天日期，可將討論的時間尺度最小至日。另外在各筆資料都記載著延遲或取消、延遲時間、原因、起降機場、兩機場距離等屬性資料。因此除了透過時間序列方法來評估、分析這組資料之外，亦可透過空間分析、影響因素分析等方式評估欲解決的問題。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 答：
# 提升車隊業績的方式有許多，可以透過增加車隊車輛、加長車隊服務時間等方式，然而在不考慮增加硬體設施及維持服務時間下，降低車隊的空車率亦是另一種提昇業績之方法。載客車隊的車輛滿街跑，卻不是輛輛都是有乘客的。為了能降低空車率，首先應該要清楚此時此刻人潮在哪，有了人潮才會有移動的需求存在。因此預測人潮在哪些地方出現，即是我所關注的問題。若能透過相關數據的收集，分析出此時此刻的人潮熱點區域，則可通知空車司機往該區域移動，以提高獲得需求的機會。若能搶先其他業者到達該人潮熱點，接獲需求的機會也會增加。因此該如何透過歷史事件的分析，進化成未來事件的推擬、預測，則會是搶先一步的關鍵。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 答：
# 可增設車隊車輛管控平台，利用此平台，收集相關乘客的需求資料，包括上下車地點、時間、即時天氣概況等時空方面的數據，作為基本的分析數據。然而除了當下的時空因素之外，亦有可能會因為其他的事件驅使需求的產生，例如道路施空或逢特地節日等，皆有可能會產生不同的載客需求。因此管控平台可將其他事件透過司機對乘客的簡單訪談，做更進一步的分類。
#
# 3. 蒐集而來的資料型態為何
#
# 答：
# 由於需求的屬性資料需做有效的處理，才能做更進一步的分析，因此在管控平台的資料收集格式，可透過表格自動填入相關屬性資料，包括上下車座標數據、時間、天氣概況，因此可預設為csv檔。然而為了因應不同事件產生的需求，需設定一欄位為司機對乘客的簡單訪談，該訪談結果可為對話，因此可透過對話內容，透過自然語言訓練處理，分類出不同的需求事件，以完整整項資料。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 答：
# 在哪些事件影響下，將增加瞬間人潮出現機率？
# (1) 運用回歸分析（MSE）將上下車地點、時間、即時天氣等數據，預測不同區域內會出現瞬間人潮的機率。
# (2) 預測哪些受眾（由（1）的預測結果）會提高瞬間人潮出現的機率（Accuracy / Receiver Operating Curve, ROC）。
